# %% [markdown]
# # EC2 Training Tutorial: Medical Image Classification
#
# Train DenseNet121 or ViT models on medical images using MONAI.

# %% [markdown]
# # Step 0: Setup

# %%
# !conda env remove --name classification-demo -y
# !conda create -n classification-demo python=3.12 -y
# !conda activate classification-demo
# !pip install -r requirements.txt
# Out:
# DirectoryNotACondaEnvironmentError: The target directory exists, but it is not a conda environment.
# Use 'conda create' to convert the directory to a conda environment.
#   target directory: /home/ubuntu/miniconda3/envs/classification-demo
#
#
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/ubuntu/miniconda3/envs/classification-demo
#
#   added / updated specs:
#     - python=3.12
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2025.12.2-h06a4308_0
#   expat              pkgs/main/linux-64::expat-2.7.4-h7354ed3_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libexpat           pkgs/main/linux-64::libexpat-2.7.4-h7354ed3_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-25.0-py312h06a4308_1
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.12.12-hd17a9e1_1
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-80.10.2-py312h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.2-h3e8d24a_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py312h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate classification-demo
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
# Requirement already satisfied: torch in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: monai==1.4.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: torchvision in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (0.24.1)
# Requirement already satisfied: itk in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: numpy==1.26.4 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: tensorboard in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 6)) (2.20.0)
# Requirement already satisfied: einops in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 7)) (0.8.1)
# Requirement already satisfied: ipykernel in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (6.29.5)
# Requirement already satisfied: tqdm in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: protobuf==3.20.* in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from -r requirements.txt (line 10)) (3.20.3)
# Requirement already satisfied: filelock in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (3.5)
# Requirement already satisfied: jinja2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torch->-r requirements.txt (line 1)) (3.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from torchvision->-r requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: itk-core==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: itk-numerics==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: itk-io==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: itk-filtering==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: itk-registration==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: itk-segmentation==5.4.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from itk->-r requirements.txt (line 4)) (5.4.5)
# Requirement already satisfied: absl-py>=0.4 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (3.10)
# Requirement already satisfied: packaging in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (24.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from tensorboard->-r requirements.txt (line 6)) (3.1.3)
# Requirement already satisfied: comm>=0.1.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (9.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (6.5)
# Requirement already satisfied: traitlets>=5.4.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipykernel->-r requirements.txt (line 8)) (5.14.3)
# Requirement already satisfied: decorator in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.19.1)
# Requirement already satisfied: stack_data in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r requirements.txt (line 8)) (4.3.7)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from werkzeug>=1.0.1->tensorboard->-r requirements.txt (line 6)) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pure_eval in /home/ubuntu/miniconda3/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.3)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Step 1: Setup
#
# Import libraries and configure logging. Check GPU availability.

# %%
import numpy as np
np.__version__
# Out:
# '1.26.4'

# %%
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
np.__version__
import monai
from monai.data import DataLoader
from monai.networks.nets import DenseNet121, ViT
from monai.transforms import Compose, LoadImage, EnsureChannelFirst, Resize, ScaleIntensity
from torch.utils.tensorboard import SummaryWriter
from tqdm import tqdm
import json
import logging
import os
import sys
import datetime
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# Logging
timestamp = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
log_dir = os.path.join(os.getcwd(), 'logs', 'log_' + timestamp)
os.makedirs(log_dir, exist_ok=True)
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s',
                   handlers=[logging.FileHandler(os.path.join(log_dir, 'app.log')),
                            logging.StreamHandler(sys.stdout)])
logger = logging.getLogger(__name__)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Device: {device}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# Device: cuda:0
# GPU: NVIDIA A10G

# %% [markdown]
# ## Step 2: Configure Training
#
# Set data paths and hyperparameters. Choose DenseNet121 or ViT architecture.

# %%
# Paths Change these paths as needed
data_dir = '/home/ubuntu/data/vindr-spinexr-subset'
model_dir = '/home/ubuntu/data/spine-model'
output_dir = '/home/ubuntu/data/spine-output'

# Hyperparameters
model_name = 'DenseNet121'  # or 'ViT'
learning_rate = 0.001
batch_size = 32
num_epochs = 3
val_interval = 10
early_stopping_rounds = 10
img_size = (256, 256, 1)

os.makedirs(os.path.join(model_dir, model_name), exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Step 3: Define Model
#
# Create ModelDef class to instantiate DenseNet121 or ViT from MONAI.

# %%
class ModelDef:
    def __init__(self, num_classes, model_name):
        self.num_classes = num_classes
        self.model_name = model_name

    def get_model(self):
        if self.model_name == "DenseNet121":
            return DenseNet121(spatial_dims=2, in_channels=1, out_channels=self.num_classes)
        elif self.model_name == "ViT":
            return ViT(in_channels=1, img_size=(256, 256, 1), patch_size=(16, 16, 1),
                      hidden_size=768, mlp_dim=3072, num_layers=12, num_heads=12,
                      classification=True, num_classes=self.num_classes)
        else:
            raise ValueError(f"Model {self.model_name} not supported.")

# %% [markdown]
# ### Create a label dictionary

# %%
list_classes = os.listdir(os.path.join(data_dir, 'train'))
label_dict = {cls: idx for idx, cls in enumerate(list_classes)}
json.dump(label_dict, open("label_dict.json", "w"), indent=4)

# %% [markdown]
# ## Step 4: Create Dataset & Loaders
#
# Build custom dataset from label_dict.json. Apply MONAI transforms and create data loaders.

# %%
class MedNISTDataset(torch.utils.data.Dataset):
    def __init__(self, image_files, labels, transforms):
        self.image_files = image_files
        self.labels = labels
        self.transforms = transforms

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, index):
        return self.transforms(self.image_files[index]), self.labels[index]


def generate_list_labels(data_folder):
    with open("label_dict.json", "r") as fid:
        label_dict = json.load(fid)
    
    image_list, label_list = [], []
    for _label in label_dict:
        label_data = os.path.join(data_folder, _label)
        if not os.path.exists(label_data):
            continue
        for _file in os.listdir(label_data):
            image_list.append(os.path.join(label_data, _file))
            label_list.append(label_dict[_label])

    c = list(zip(image_list, label_list))
    random.shuffle(c)
    image_list, label_list = zip(*c)
    return image_list, label_list, len(label_dict)


def create_data_loaders(data, batch_size):
    transforms = Compose([LoadImage(), EnsureChannelFirst(), 
                         Resize(spatial_size=img_size), ScaleIntensity()])
    
    train_img, train_lbl, num_classes = generate_list_labels(os.path.join(data, 'train'))
    val_img, val_lbl, _ = generate_list_labels(os.path.join(data, 'valid'))
    test_img, test_lbl, _ = generate_list_labels(os.path.join(data, 'test'))

    train_ds = MedNISTDataset(train_img, train_lbl, transforms)
    val_ds = MedNISTDataset(val_img, val_lbl, transforms)
    test_ds = MedNISTDataset(test_img, test_lbl, transforms)
    
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=16)
    val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=True, num_workers=16)
    test_loader = DataLoader(test_ds, batch_size=batch_size, shuffle=True, num_workers=16)
    
    return train_loader, test_loader, val_loader, num_classes


train_loader, test_loader, validation_loader, num_classes = create_data_loaders(data_dir, batch_size)
logger.info(f'Classes: {num_classes}, Train: {len(train_loader.dataset)}, Val: {len(validation_loader.dataset)}')
# Out:
# 2026-03-15 07:32:00,287 - Classes: 8, Train: 80, Val: 80
# This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.

# %% [markdown]
# ## Step 5: Define Training Functions
#
# Implement test() for validation and train() with early stopping and TensorBoard logging.

# %%
def test(model, test_loader, criterion, device, model_name):
    running_loss = 0
    running_corrects = 0
    
    with torch.no_grad():
        for inputs, labels in tqdm(test_loader, desc="Validation"):
            inputs, labels = inputs.to(device), labels.to(device)
            
            if model_name == 'DenseNet121':
                outputs = model(inputs[:, :, :, :, 0])
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
            else:
                outputs = model(inputs)
                loss = criterion(outputs[0], labels)
                _, preds = torch.max(outputs[0], 1)
                
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data).item()

    total_loss = running_loss / len(test_loader.dataset)
    total_acc = running_corrects / len(test_loader.dataset)
    logger.info(f"Val Loss: {total_loss:.4f}, Val Acc: {total_acc:.4f}")
    return total_loss, total_acc


def train(model, train_loader, validation_loader, criterion, optimizer, device, 
          model_name, num_epochs, val_interval, early_stopping_rounds, model_dir, output_dir):
    best_loss = 1e6
    loss_counter = 0
    writer = SummaryWriter(log_dir=os.path.join(output_dir, model_name, 'logs'))

    for epoch in range(num_epochs):
        model.train()
        running_loss, running_corrects, running_samples = 0.0, 0, 0
        print(f"\nEpoch {epoch}/{num_epochs}")

        for step, (inputs, labels) in enumerate(tqdm(train_loader)):
            inputs, labels = inputs.to(device), labels.to(device)
            
            if model_name == 'DenseNet121':
                outputs = model(inputs[:, :, :, :, 0])
                loss = criterion(outputs, labels)
                _, preds = torch.max(outputs, 1)
            else:
                outputs = model(inputs)
                loss = criterion(outputs[0], labels)
                _, preds = torch.max(outputs[0], 1)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data).item()
            running_samples += len(inputs)
            
            if running_samples % 4000 == 0:
                accuracy = running_corrects / running_samples
                logger.info(f"[{running_samples}/{len(train_loader.dataset)}] Loss: {loss.item():.2f}, Acc: {accuracy:.4f}")
                writer.add_scalar('train/accuracy', accuracy, epoch * len(train_loader) + step)

            writer.add_scalar('train/loss', loss.item(), epoch * len(train_loader) + step)
            
        epoch_loss = running_loss / running_samples
        epoch_acc = running_corrects / running_samples

        if epoch % val_interval == 0:
            model.eval()
            val_loss, val_acc = test(model, validation_loader, criterion, device, model_name)
            
            if val_loss < best_loss:
                best_loss = val_loss
                torch.save(model.state_dict(), os.path.join(model_dir, model_name, f'best_model_{epoch}.pth'))
                logger.info(f"✓ Saved best model (loss: {best_loss:.4f})")
            else:
                loss_counter += 1
                
            logger.info(f'Epoch {epoch}: Train Loss={epoch_loss:.4f}, Train Acc={epoch_acc:.4f}, Val Loss={val_loss:.4f}')
            writer.add_scalar('val/loss', val_loss, epoch)
            writer.add_scalar('val/accuracy', val_acc, epoch)
            
        if loss_counter == early_stopping_rounds:
            logger.info('Early stopping triggered')
            break
            
    writer.close()
    return model

# %% [markdown]
# ## Step 6: Train Model
#
# Initialize model, optimizer, and loss function. Run training loop.

# %%
# Initialize
model = ModelDef(num_classes, model_name).get_model().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

logger.info(f"Starting training: {model_name} with {num_classes} classes")

# Train
model = train(model, train_loader, validation_loader, criterion, optimizer, device,
             model_name, num_epochs, val_interval, early_stopping_rounds, model_dir, output_dir)
# Out:
# 2026-03-15 07:32:13,447 - Starting training: DenseNet121 with 8 classes
#
# Epoch 0/3
# 100%|██████████| 3/3 [00:19<00:00,  6.46s/it]
# Validation: 100%|██████████| 3/3 [00:17<00:00,  5.67s/it]
# 2026-03-15 07:32:49,841 - Val Loss: 4.2955, Val Acc: 0.1250
# 2026-03-15 07:32:49,989 - ✓ Saved best model (loss: 4.2955)
# 2026-03-15 07:32:49,990 - Epoch 0: Train Loss=2.0930, Train Acc=0.1625, Val Loss=4.2955
# Epoch 1/3
# 100%|██████████| 3/3 [00:16<00:00,  5.43s/it]
# Epoch 2/3
# 100%|██████████| 3/3 [00:16<00:00,  5.42s/it]

# %% [markdown]
# ## Step 7: Save Model
#
# Save final trained model weights to disk.

# %%
out_dir = os.path.join(output_dir, model_name)
os.makedirs(out_dir, exist_ok=True)
torch.save(model.state_dict(), os.path.join(out_dir, "model.pth"))
logger.info(f"Model saved to {os.path.join(out_dir, 'model.pth')}")
# Out:
# 2026-03-15 07:33:57,501 - Model saved to /home/ubuntu/data/spine-output/DenseNet121/model.pth

# %% [markdown]
# ## View TensorBoard
#
# ```bash
# tensorboard --logdir=./logs
# ```
